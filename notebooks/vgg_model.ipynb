# %% [markdown]
# In this notebook, using VGG16 with Batch Normalization and adding own fully-connected layers.  Also, in lieu of pre-processed image data loaded into single tensors (one for train, validation and test, respectively), will revert back to the flow_from_directory method from Keras (applying to pre-cropped images as per the annotation data provided by the Stanford dataset).

# %%
import numpy as np
from keras.models import Sequential
from utils_channels_last import Vgg16BN
from keras.utils.np_utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD, RMSprop, Adam
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.models import Model

from keras import backend as K

# %%
import os

from tensorflow.python.client import device_lib
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"]="0" #for training on gpu
print(device_lib.list_local_devices())

# configure tensorflow before fitting model
tf_config = tf.ConfigProto()
tf_config.gpu_options.per_process_gpu_memory_fraction = 0.99
sess = tf.Session(config=tf_config)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3973042051247644799
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1494830284
# locality {
#   bus_id: 1
# }
# incarnation: 5580222334547750882
# physical_device_desc: "device: 0, name: GeForce GTX 860M, pci bus id: 0000:01:00.0, compute capability: 5.0"
# ]

# %%
# changing directory for flow_from_directory method
os.chdir('C:\\Users\\Garrick\\Documents\\Springboard\\Capstone Project 2\\datasets')

# %% [markdown]
# ## Classifying the Dog Breed Using (Transfer Leraning)
# Here we are using  pretrained VGG16BN network, which is a VGG16 architecture with Batch Normalization.  This addition of Batch Normalization is useful in my case as we have such few samples per class and aids in overfitting.  However, this doesn't meant that overfitting is avoidable.

# %%
batch_size=12
num_classes = 120
image_size = 224
num_channels = 3

# %% [markdown]
# ## IMAGE DATA  AUGMENTATION
# Here we use data Augmentation as Described in the previous post.

# %%
train_datagen = ImageDataGenerator(rotation_range=15, shear_range=0.1, channel_shift_range=20,
                                    width_shift_range=0.1,  height_shift_range=0.1, zoom_range=0.1, horizontal_flip=True,
                                  validation_split=0.2)

test_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory('cropped/train', target_size=(224,224),
            class_mode='categorical', shuffle=True, batch_size=batch_size, subset='training')

validation_generator = train_datagen.flow_from_directory('cropped/train', target_size=(224,224),
            class_mode='categorical', shuffle=True, batch_size=batch_size, subset='validation')

test_generator = test_datagen.flow_from_directory('cropped/test', target_size=(224,224),
            class_mode='categorical', shuffle=False, batch_size=batch_size)
# Out:
# Found 9600 images belonging to 120 classes.
# Found 2400 images belonging to 120 classes.
# Found 8580 images belonging to 120 classes.

# %%
base_model = Vgg16BN(include_top=False).model
x = base_model.output
x = Flatten()(x)
x = Dropout(0.4)(x)
# let's add two fully-connected layer
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
# and a final FC layer with 'softmax' activation since we are doing a multi-class problem 
predictions = Dense(num_classes, activation='softmax')(x)

# this is the model we will train
model = Model(input=base_model.input, output=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer=Adam(lr=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# C:\Users\Garrick\Documents\GitHub\DOG-BREED-CLASSIFICATION-STANFORD-DOG-DATASET\utils_channels_last.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   model.add(Convolution2D(filters, 3, 3, activation='relu'))
# C:\Users\Garrick\Documents\GitHub\DOG-BREED-CLASSIFICATION-STANFORD-DOG-DATASET\utils_channels_last.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu")`
#   model.add(Convolution2D(filters, 3, 3, activation='relu'))
# C:\Users\Garrick\Documents\GitHub\DOG-BREED-CLASSIFICATION-STANFORD-DOG-DATASET\utils_channels_last.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu")`
#   model.add(Convolution2D(filters, 3, 3, activation='relu'))
# C:\Users\Garrick\Documents\GitHub\DOG-BREED-CLASSIFICATION-STANFORD-DOG-DATASET\utils_channels_last.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu")`
#   model.add(Convolution2D(filters, 3, 3, activation='relu'))
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_3_input (InputLayer)  (None, 3, 224, 224)       0
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 3, 224, 224)       0
# _________________________________________________________________
# zero_padding2d_27 (ZeroPaddi (None, 3, 226, 226)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 64, 224, 224)      1792
# _________________________________________________________________
# zero_padding2d_28 (ZeroPaddi (None, 64, 226, 226)      0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 64, 224, 224)      36928
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 64, 112, 112)      0
# _________________________________________________________________
# zero_padding2d_29 (ZeroPaddi (None, 64, 114, 114)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 128, 112, 112)     73856
# _________________________________________________________________
# zero_padding2d_30 (ZeroPaddi (None, 128, 114, 114)     0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 128, 112, 112)     147584
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 128, 56, 56)       0
# _________________________________________________________________
# zero_padding2d_31 (ZeroPaddi (None, 128, 58, 58)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 256, 56, 56)       295168
# _________________________________________________________________
# zero_padding2d_32 (ZeroPaddi (None, 256, 58, 58)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 256, 56, 56)       590080
# _________________________________________________________________
# zero_padding2d_33 (ZeroPaddi (None, 256, 58, 58)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 256, 56, 56)       590080
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 256, 28, 28)       0
# _________________________________________________________________
# zero_padding2d_34 (ZeroPaddi (None, 256, 30, 30)       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 512, 28, 28)       1180160
# _________________________________________________________________
# zero_padding2d_35 (ZeroPaddi (None, 512, 30, 30)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 512, 28, 28)       2359808
# _________________________________________________________________
# zero_padding2d_36 (ZeroPaddi (None, 512, 30, 30)       0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 512, 28, 28)       2359808
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 512, 14, 14)       0
# _________________________________________________________________
# zero_padding2d_37 (ZeroPaddi (None, 512, 16, 16)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 512, 14, 14)       2359808
# _________________________________________________________________
# zero_padding2d_38 (ZeroPaddi (None, 512, 16, 16)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 512, 14, 14)       2359808
# _________________________________________________________________
# zero_padding2d_39 (ZeroPaddi (None, 512, 16, 16)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 512, 14, 14)       2359808
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 512, 7, 7)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 120)               30840
# =================================================================
# Total params: 27,725,496
# Trainable params: 13,009,272
# Non-trainable params: 14,716,224
# _________________________________________________________________
# None
# c:\users\garrick\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("la..., outputs=Tensor("de...)`
#   app.launch_new_instance()

# %%
from keras.callbacks import ModelCheckpoint

# %%
model.load_weights('saved_models/weights.vgg16_BN_finetuned.h5')

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5', 
                               verbose=1, save_best_only=True)


history = model.fit_generator(train_generator, steps_per_epoch=800, epochs=25, 
                              validation_data=validation_generator,
                              callbacks=[checkpointer])
# Out:
# Epoch 1/25
# 800/800 [==============================] - 444s 555ms/step - loss: 4.4294 - acc: 0.0727 - val_loss: 3.4439 - val_acc: 0.1908
#
# Epoch 00001: val_loss improved from inf to 3.44385, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 2/25
# 800/800 [==============================] - 401s 501ms/step - loss: 3.5030 - acc: 0.1753 - val_loss: 2.8733 - val_acc: 0.3125
#
# Epoch 00002: val_loss improved from 3.44385 to 2.87333, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 3/25
# 800/800 [==============================] - 401s 502ms/step - loss: 3.0068 - acc: 0.2560 - val_loss: 2.5689 - val_acc: 0.3767
#
# Epoch 00003: val_loss improved from 2.87333 to 2.56890, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 4/25
# 800/800 [==============================] - 402s 502ms/step - loss: 2.6733 - acc: 0.3266 - val_loss: 2.3388 - val_acc: 0.4217
#
# Epoch 00004: val_loss improved from 2.56890 to 2.33881, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 5/25
# 800/800 [==============================] - 401s 501ms/step - loss: 2.4431 - acc: 0.3647 - val_loss: 2.2090 - val_acc: 0.4404
#
# Epoch 00005: val_loss improved from 2.33881 to 2.20897, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 6/25
# 800/800 [==============================] - 401s 502ms/step - loss: 2.2418 - acc: 0.4081 - val_loss: 2.0926 - val_acc: 0.4575
#
# Epoch 00006: val_loss improved from 2.20897 to 2.09259, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 7/25
# 800/800 [==============================] - 402s 502ms/step - loss: 2.0839 - acc: 0.4504 - val_loss: 1.9876 - val_acc: 0.4825
#
# Epoch 00007: val_loss improved from 2.09259 to 1.98758, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 8/25
# 800/800 [==============================] - 403s 503ms/step - loss: 1.9562 - acc: 0.4756 - val_loss: 1.9483 - val_acc: 0.4846
#
# Epoch 00008: val_loss improved from 1.98758 to 1.94832, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 9/25
# 800/800 [==============================] - 402s 502ms/step - loss: 1.8457 - acc: 0.5060 - val_loss: 1.8850 - val_acc: 0.5004
#
# Epoch 00009: val_loss improved from 1.94832 to 1.88503, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 10/25
# 800/800 [==============================] - 405s 506ms/step - loss: 1.7638 - acc: 0.5223 - val_loss: 1.8239 - val_acc: 0.5150
#
# Epoch 00010: val_loss improved from 1.88503 to 1.82386, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 11/25
# 800/800 [==============================] - 406s 507ms/step - loss: 1.6711 - acc: 0.5380 - val_loss: 1.8227 - val_acc: 0.4946
#
# Epoch 00011: val_loss improved from 1.82386 to 1.82275, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 12/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.6053 - acc: 0.5632 - val_loss: 1.7780 - val_acc: 0.5129
#
# Epoch 00012: val_loss improved from 1.82275 to 1.77798, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 13/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.5416 - acc: 0.5699 - val_loss: 1.7458 - val_acc: 0.5317
#
# Epoch 00013: val_loss improved from 1.77798 to 1.74579, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 14/25
# 800/800 [==============================] - 402s 502ms/step - loss: 1.4783 - acc: 0.5895 - val_loss: 1.7225 - val_acc: 0.5179
#
# Epoch 00014: val_loss improved from 1.74579 to 1.72251, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 15/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.4332 - acc: 0.6025 - val_loss: 1.7000 - val_acc: 0.5292
#
# Epoch 00015: val_loss improved from 1.72251 to 1.70000, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 16/25
# 800/800 [==============================] - 404s 504ms/step - loss: 1.3773 - acc: 0.6105 - val_loss: 1.7004 - val_acc: 0.5417
#
# Epoch 00016: val_loss did not improve
# Epoch 17/25
# 800/800 [==============================] - 405s 506ms/step - loss: 1.3533 - acc: 0.6231 - val_loss: 1.6989 - val_acc: 0.5237
#
# Epoch 00017: val_loss improved from 1.70000 to 1.69892, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 18/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.2967 - acc: 0.6314 - val_loss: 1.6774 - val_acc: 0.5229
#
# Epoch 00018: val_loss improved from 1.69892 to 1.67739, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 19/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.2634 - acc: 0.6408 - val_loss: 1.6640 - val_acc: 0.5333
#
# Epoch 00019: val_loss improved from 1.67739 to 1.66403, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 20/25
# 800/800 [==============================] - 405s 507ms/step - loss: 1.2402 - acc: 0.6455 - val_loss: 1.7053 - val_acc: 0.5183
#
# Epoch 00020: val_loss did not improve
# Epoch 21/25
# 800/800 [==============================] - 407s 509ms/step - loss: 1.1894 - acc: 0.6575 - val_loss: 1.6675 - val_acc: 0.5229
#
# Epoch 00021: val_loss did not improve
# Epoch 22/25
# 800/800 [==============================] - 407s 509ms/step - loss: 1.1375 - acc: 0.6762 - val_loss: 1.6534 - val_acc: 0.5367
#
# Epoch 00022: val_loss improved from 1.66403 to 1.65343, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 23/25
# 800/800 [==============================] - 406s 508ms/step - loss: 1.1336 - acc: 0.6779 - val_loss: 1.6312 - val_acc: 0.5454
#
# Epoch 00023: val_loss improved from 1.65343 to 1.63116, saving model to saved_models/weights.bestaugmented.pre_trained_vgg16_v3.hdf5
# Epoch 24/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.0811 - acc: 0.6881 - val_loss: 1.6816 - val_acc: 0.5287
#
# Epoch 00024: val_loss did not improve
# Epoch 25/25
# 800/800 [==============================] - 404s 505ms/step - loss: 1.0690 - acc: 0.6928 - val_loss: 1.6548 - val_acc: 0.5450
#
# Epoch 00025: val_loss did not improve

# %%
# saving what we have so far
model.save('saved_models/vgg16_BN_finetuned.h5')
model.save_weights('saved_models/weights.vgg16_BN_finetuned.h5')

# %%
# not sure if I need this later but saving the classes from the generator object and the respective indices
label_dict = train_generator.class_indices

# %%
# lets plot/visualize the model training progress

import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('bmh')

font = {'family' : 'sans-serif',
        'weight' : 'medium',
        'size'   : 16}

plt.rc('font', **font)

# %%
def plot_history(history, figsize=(8,8)):
    '''
    Args: the history attribute of model.fit, figure size (defaults to (8,8))
    Description: Takes the history object and plots the loss and accuracy metrics (both train and validation)
    Returns: Plots of Loss and Accuracy from model training
    '''
    loss_list = [s for s in history.history.keys() if 'loss' in s and 'val' not in s]
    val_loss_list = [s for s in history.history.keys() if 'loss' in s and 'val' in s]
    acc_list = [s for s in history.history.keys() if 'acc' in s and 'val' not in s]
    val_acc_list = [s for s in history.history.keys() if 'acc' in s and 'val' in s]
    
    if len(loss_list) == 0:
        print('Loss is missing in history')
        return 
    
    ## As loss always exists
    epochs = range(1,len(history.history[loss_list[0]]) + 1)
    
    ## Loss
    plt.figure(1, figsize=figsize)
    for l in loss_list:
        plt.plot(epochs, history.history[l], 'b', label='Training loss (' + str(str(format(history.history[l][-1],'.5f'))+')'))
    for l in val_loss_list:
        plt.plot(epochs, history.history[l], 'g', label='Validation loss (' + str(str(format(history.history[l][-1],'.5f'))+')'))
    
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    legend = plt.legend(frameon = 1)
    frame = legend.get_frame()
    frame.set_color('white')
    
    ## Accuracy
    plt.figure(2, figsize=figsize)
    for l in acc_list:
        plt.plot(epochs, history.history[l], 'b', label='Training accuracy (' + str(format(history.history[l][-1],'.5f'))+')')
    for l in val_acc_list:    
        plt.plot(epochs, history.history[l], 'g', label='Validation accuracy (' + str(format(history.history[l][-1],'.5f'))+')')

    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    legend = plt.legend(frameon = 1)
    frame = legend.get_frame()
    frame.set_color('white')
    plt.show()

# %%
plot_history(history, figsize=(10,6))

# %%
# looks like we're starting to overfit, let's see if we can improve by continuing to train with a slower learning rate 
# as gains in val_loss are becoming less frequent

model.optimizer.lr = 1e6
history = model.fit_generator(train_generator, steps_per_epoch=800, epochs=15, 
                        validation_data=validation_generator,
                       callbacks=[checkpointer])
# Out:
# Epoch 1/15
# 800/800 [==============================] - 407s 509ms/step - loss: 1.0207 - acc: 0.7031 - val_loss: 1.6696 - val_acc: 0.5296
#
# Epoch 00001: val_loss did not improve
# Epoch 2/15
# 800/800 [==============================] - 408s 510ms/step - loss: 0.9880 - acc: 0.7120 - val_loss: 1.6594 - val_acc: 0.5383
#
# Epoch 00002: val_loss did not improve
# Epoch 3/15
# 800/800 [==============================] - 407s 509ms/step - loss: 1.0013 - acc: 0.7094 - val_loss: 1.6362 - val_acc: 0.5392
#
# Epoch 00003: val_loss did not improve
# Epoch 4/15
# 800/800 [==============================] - 410s 513ms/step - loss: 0.9941 - acc: 0.7116 - val_loss: 1.6371 - val_acc: 0.5342
#
# Epoch 00004: val_loss did not improve
# Epoch 5/15
# 800/800 [==============================] - 407s 509ms/step - loss: 0.9626 - acc: 0.7216 - val_loss: 1.6739 - val_acc: 0.5321
#
# Epoch 00005: val_loss did not improve
# Epoch 6/15
# 800/800 [==============================] - 408s 510ms/step - loss: 0.9289 - acc: 0.7285 - val_loss: 1.6792 - val_acc: 0.5337
#
# Epoch 00006: val_loss did not improve
# Epoch 7/15
# 800/800 [==============================] - 410s 513ms/step - loss: 0.9148 - acc: 0.7347 - val_loss: 1.6639 - val_acc: 0.5400
#
# Epoch 00007: val_loss did not improve
# Epoch 8/15
# 800/800 [==============================] - 406s 508ms/step - loss: 0.8770 - acc: 0.7381 - val_loss: 1.6984 - val_acc: 0.5250
#
# Epoch 00008: val_loss did not improve
# Epoch 9/15
# 800/800 [==============================] - 408s 510ms/step - loss: 0.8761 - acc: 0.7379 - val_loss: 1.6894 - val_acc: 0.5358
#
# Epoch 00009: val_loss did not improve
# Epoch 10/15
# 800/800 [==============================] - 408s 510ms/step - loss: 0.8520 - acc: 0.7474 - val_loss: 1.6983 - val_acc: 0.5279
#
# Epoch 00010: val_loss did not improve
# Epoch 11/15
# 800/800 [==============================] - 408s 510ms/step - loss: 0.8352 - acc: 0.7517 - val_loss: 1.6469 - val_acc: 0.5492
#
# Epoch 00011: val_loss did not improve
# Epoch 12/15
# 800/800 [==============================] - 407s 509ms/step - loss: 0.8450 - acc: 0.7493 - val_loss: 1.6611 - val_acc: 0.5367
#
# Epoch 00012: val_loss did not improve
# Epoch 13/15
# 800/800 [==============================] - 406s 508ms/step - loss: 0.8180 - acc: 0.7565 - val_loss: 1.7071 - val_acc: 0.5292
#
# Epoch 00013: val_loss did not improve
# Epoch 14/15
# 800/800 [==============================] - 404s 505ms/step - loss: 0.7981 - acc: 0.7619 - val_loss: 1.6897 - val_acc: 0.5479
#
# Epoch 00014: val_loss did not improve
# Epoch 15/15
# 800/800 [==============================] - 406s 507ms/step - loss: 0.7935 - acc: 0.7650 - val_loss: 1.7034 - val_acc: 0.5312
#
# Epoch 00015: val_loss did not improve

# %%
plot_history(history, figsize=(10,6))

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score 
import itertools

# %%
# now lets evaluate the model on our unseen test data

y_pred = model.predict_generator(test_generator, max_queue_size =10)

# %%
y_pred = np.argmax(y_pred, axis=1).astype(int)
y_pred
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-54-541c367a4e96> in <module>()
# ----> 1 y_pred = np.argmax(y_pred, axis=1).astype(int)
#       2 y_pred
#
# c:\users\garrick\anaconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py in argmax(a, axis, out)
#    1002
#    1003     """
# -> 1004     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1005
#    1006
#
# c:\users\garrick\anaconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      50 def _wrapfunc(obj, method, *args, **kwds):
#      51     try:
# ---> 52         return getattr(obj, method)(*args, **kwds)
#      53
#      54     # An AttributeError occurs if the object does not have
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
test_labels = np.load(open('test_labels.npy','rb'))

# %%
cm = confusion_matrix(test_labels, y_pred)

# %%
breeds = label_dict.keys()

# %%
import seaborn as sns
import pandas as pd

# %%
fig, ax = plt.subplots(figsize=(30, 26))
plt.title('Confusion Matrix on Test Images')
_ = sns.heatmap(cm, ax=ax, yticklabels=breeds, xticklabels=breeds, robust=True)

# %%
accuracy = model.evaluate_generator(test_generator, max_queue_size=10)

# %%
print(accuracy)
# Out:
# [1.4146448807699696, 0.5895104877390228]

# %%
'''

# credit to: https://gist.github.com/nickynicolson/202fe765c99af49acb20ea9f77b6255e

def cm2df(cm, labels):
    df = pd.DataFrame()
    # rows
    for i, row_label in enumerate(labels):
        rowdata={}
        # columns
        for j, col_label in enumerate(labels): 
            rowdata[col_label]=cm[i,j]
        df = df.append(pd.DataFrame.from_dict({row_label:rowdata}, orient='index'))
    return df

df = cm2df(cm, breeds)
'''

# %%
df = pd.DataFrame(y_pred, columns=['predicted'], dtype='int')

# %%
df.head()
# Out:
#    predicted
# 0          0
# 1          0
# 2          0
# 3         20
# 4         20

# %%
df['actual'] = pd.Series(test_labels).astype('int')
df['count'] = 1
df['count'] = df['count'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8580 entries, 0 to 8579
# Data columns (total 3 columns):
# predicted    8580 non-null int32
# actual       8580 non-null int32
# count        8580 non-null int32
# dtypes: int32(3)
# memory usage: 100.6 KB

# %%
# need to create dictionary to assign the numeric labels to string labels 
# first let's reverse the order of the label_dict (again this was datagen.class_indices)

label_dict = {y:x for x,y in label_dict.items()}

# %%
for key, value in label_dict.items():
    label_dict[key] = value[10:]

# %%
df.replace({"actual": label_dict}, inplace=True)
df.replace({"predicted": label_dict}, inplace=True)

# %%
df.head()
# Out:
#            predicted     actual  count
# 0          Chihuahua  Chihuahua      1
# 1          Chihuahua  Chihuahua      1
# 2          Chihuahua  Chihuahua      1
# 3  Italian_greyhound  Chihuahua      1
# 4  Italian_greyhound  Chihuahua      1

# %%
# let's take a look at the top 30 most confused pairs

misclass_df = df[df['actual'] != df['predicted']].groupby(['actual', 'predicted']).sum().sort_values(['count'], ascending=False).reset_index()
misclass_df['pair'] = misclass_df['actual'] + ' / ' + misclass_df['predicted']
misclass_df = misclass_df[['pair', 'count']].take(range(30))

misclass_df.sort_values(['count']).plot.barh(figsize=(8, 10), x=misclass_df['pair'])
plt.title('Top 30 Misclassified Breed Pairs')
# Out:
# Text(0.5,1,'Top 30 Misclassified Breed Pairs')

# %%
# https://stackoverflow.com/questions/41695844/keras-showing-images-from-data-generator?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa

x,y = train_generator.next()
for i in range(0,5):
    image = x[i]
    plt.imshow(image.transpose(2,1,0))
    plt.show()

# %%
# finally let's get the classification report in case we need it

print(classification_report(y_true=test_labels, y_pred=y_pred, target_names=list(label_dict.values())))
# Out:
#                                 precision    recall  f1-score   support
#
#                      Chihuahua       0.49      0.40      0.44        52
#               Japanese_spaniel       0.66      0.81      0.73        85
#                    Maltese_dog       0.82      0.71      0.76       152
#                       Pekinese       0.36      0.43      0.39        49
#                       Shih-Tzu       0.42      0.42      0.42       114
#               Blenheim_spaniel       0.76      0.73      0.74        88
#                       papillon       0.73      0.76      0.74        96
#                    toy_terrier       0.60      0.60      0.60        72
#            Rhodesian_ridgeback       0.35      0.46      0.40        72
#                   Afghan_hound       0.87      0.85      0.86       139
#                         basset       0.60      0.63      0.61        75
#                         beagle       0.54      0.46      0.50        95
#                     bloodhound       0.70      0.57      0.63        87
#                       bluetick       0.72      0.73      0.73        71
#        black-and-tan_coonhound       0.52      0.58      0.54        59
#                   Walker_hound       0.35      0.45      0.39        53
#               English_foxhound       0.55      0.54      0.55        57
#                        redbone       0.35      0.50      0.41        48
#                         borzoi       0.48      0.47      0.48        51
#                Irish_wolfhound       0.59      0.55      0.57       118
#              Italian_greyhound       0.46      0.33      0.38        82
#                        whippet       0.50      0.34      0.41        87
#                   Ibizan_hound       0.68      0.65      0.66        88
#             Norwegian_elkhound       0.76      0.91      0.83        96
#                     otterhound       0.52      0.63      0.57        51
#                         Saluki       0.69      0.59      0.63       100
#             Scottish_deerhound       0.77      0.67      0.72       132
#                     Weimaraner       0.62      0.80      0.70        60
#      Staffordshire_bullterrier       0.53      0.47      0.50        55
# American_Staffordshire_terrier       0.38      0.31      0.34        64
#             Bedlington_terrier       0.81      0.82      0.81        82
#                 Border_terrier       0.60      0.53      0.56        72
#             Kerry_blue_terrier       0.74      0.71      0.72        79
#                  Irish_terrier       0.59      0.55      0.57        69
#                Norfolk_terrier       0.46      0.58      0.52        72
#                Norwich_terrier       0.50      0.41      0.45        85
#              Yorkshire_terrier       0.43      0.59      0.50        64
#        wire-haired_fox_terrier       0.67      0.58      0.62        57
#               Lakeland_terrier       0.58      0.39      0.47        97
#               Sealyham_terrier       0.80      0.77      0.79       102
#                       Airedale       0.75      0.66      0.70       102
#                          cairn       0.55      0.43      0.49        97
#             Australian_terrier       0.58      0.64      0.60        96
#                 Dandie_Dinmont       0.73      0.50      0.59        80
#                    Boston_bull       0.59      0.68      0.63        82
#            miniature_schnauzer       0.43      0.48      0.45        54
#                           chow       0.80      0.83      0.82        96
#                       keeshond       0.68      0.90      0.78        58
#              Brabancon_griffon       0.75      0.74      0.74        53
#                       Pembroke       0.63      0.74      0.68        81
#                       Cardigan       0.60      0.45      0.52        55
#                     toy_poodle       0.49      0.41      0.45        51
#               miniature_poodle       0.31      0.29      0.30        55
#                standard_poodle       0.41      0.36      0.38        59
#               Mexican_hairless       0.58      0.80      0.67        55
#                          dingo       0.52      0.61      0.56        56
#                          dhole       0.69      0.80      0.74        50
#            African_hunting_dog       0.78      0.90      0.83        69
#
#                    avg / total       0.60      0.60      0.60      8580

# %%
# now let's visualize whats going on in the network itself as we pass images through
# adopted from Keras documentation: https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
from keras import backend as K

from __future__ import print_function

from scipy.misc import imsave
import time

# %%
img_width = 224
img_height = 224

# %%
layer_name = 'conv2d_13'

# %%
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + K.epsilon())
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    if K.image_data_format() == 'channels_first':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
input_img = model.input

# %%
def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + K.epsilon())

# %%
kept_filters = []
for filter_index in range(200):
    # we only scan through the first 200 filters,
    # but there are actually 512 of them
    print('Processing filter %d' % filter_index)
    start_time = time.time()

    # we build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    if K.image_data_format() == 'channels_first':
        loss = K.mean(layer_output[:, filter_index, :, :])
    else:
        loss = K.mean(layer_output[:, :, :, filter_index])

    # we compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads = normalize(grads)

    # this function returns the loss and grads given the input picture
    iterate = K.function([input_img], [loss, grads])

    # step size for gradient ascent
    step = 1.

    # we start from a gray image with some random noise
    if K.image_data_format() == 'channels_first':
        input_img_data = np.random.random((1, 3, img_width, img_height))
    else:
        input_img_data = np.random.random((1, img_width, img_height, 3))
    input_img_data = (input_img_data - 0.5) * 20 + 128

    # we run gradient ascent for 20 steps
    for i in range(20):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step

        print('Current loss value:', loss_value)
        if loss_value <= 0.:
            # some filters get stuck to 0, we can skip them
            break

    # decode the resulting input image
    if loss_value > 0:
        img = deprocess_image(input_img_data[0])
        kept_filters.append((img, loss_value))
    end_time = time.time()
    print('Filter %d processed in %ds' % (filter_index, end_time - start_time))
# Out:
# Processing filter 0
# Current loss value: 0.0
# Filter 0 processed in 1s
# Processing filter 1
# Current loss value: 0.0
# Filter 1 processed in 0s
# Processing filter 2
# Current loss value: 0.0
# Filter 2 processed in 0s
# Processing filter 3
# Current loss value: 0.0
# Filter 3 processed in 2s
# Processing filter 4
# Current loss value: 0.045308124
# Current loss value: 1.243215
# Current loss value: 4.517232
# Current loss value: 10.951656
# Current loss value: 17.517471
# Current loss value: 25.253654
# Current loss value: 33.413002
# Current loss value: 44.13913
# Current loss value: 55.58789
# Current loss value: 68.8327
# Current loss value: 80.72998
# Current loss value: 95.420616
# Current loss value: 109.65908
# Current loss value: 123.103584
# Current loss value: 137.3265
# Current loss value: 151.17468
# Current loss value: 166.62125
# Current loss value: 181.97702
# Current loss value: 200.05136
# Current loss value: 215.78633
# Filter 4 processed in 1s
# Processing filter 5
# Current loss value: 0.0
# Filter 5 processed in 0s
# Processing filter 6
# Current loss value: 0.0
# Filter 6 processed in 0s
# Processing filter 7
# Current loss value: 0.0
# Filter 7 processed in 0s
# Processing filter 8
# Current loss value: 0.0
# Filter 8 processed in 0s
# Processing filter 9
# Current loss value: 0.0
# Filter 9 processed in 0s
# Processing filter 10
# Current loss value: 0.0
# Filter 10 processed in 0s
# Processing filter 11
# Current loss value: 0.0
# Filter 11 processed in 0s
# Processing filter 12
# Current loss value: 0.0
# Filter 12 processed in 0s
# Processing filter 13
# Current loss value: 0.0
# Filter 13 processed in 0s
# Processing filter 14
# Current loss value: 0.0
# Current loss value: 163.10478
# Current loss value: 180.24251
# Current loss value: 193.1405
# Filter 187 processed in 3s
# Processing filter 188
# Current loss value: 0.0
# Filter 188 processed in 2s
# Processing filter 189
# Current loss value: 0.0
# Filter 189 processed in 2s
# Processing filter 190
# Current loss value: 0.0
# Filter 190 processed in 2s
# Processing filter 191
# Current loss value: 0.0
# Filter 191 processed in 2s
# Processing filter 192
# Current loss value: 0.0
# Filter 192 processed in 2s
# Processing filter 193
# Current loss value: 0.010456202
# Current loss value: 0.003320145
# Current loss value: 0.24268068
# Current loss value: 1.4600648
# Current loss value: 3.8580098
# Current loss value: 5.9215226
# Current loss value: 10.114223
# Current loss value: 15.342439
# Current loss value: 20.12809
# Current loss value: 29.16043
# Current loss value: 38.213757
# Current loss value: 43.79181
# Current loss value: 54.241844
# Current loss value: 62.262146
# Current loss value: 70.34376
# Current loss value: 78.97597
# Current loss value: 89.50914
# Current loss value: 98.297455
# Current loss value: 106.793434
# Current loss value: 116.63471
# Filter 193 processed in 3s
# Processing filter 194
# Current loss value: 0.0
# Filter 194 processed in 2s
# Processing filter 195
# Current loss value: 0.0
# Filter 195 processed in 2s
# Processing filter 196
# Current loss value: 0.023349999
# Current loss value: 0.476054
# Current loss value: 1.9111129
# Current loss value: 5.2935452
# Current loss value: 12.151034
# Current loss value: 19.162004
# Current loss value: 24.795767
# Current loss value: 33.49659
# Current loss value: 42.473618
# Current loss value: 51.9863
# Current loss value: 61.499443
# Current loss value: 67.70289
# Current loss value: 78.18985
# Current loss value: 85.72488
# Current loss value: 97.28216
# Current loss value: 108.75368
# Current loss value: 116.69753
# Current loss value: 126.65771
# Current loss value: 134.59068
# Current loss value: 146.51935
# Filter 196 processed in 3s
# Processing filter 197
# Current loss value: 0.0
# Filter 197 processed in 2s
# Processing filter 198
# Current loss value: 0.0
# Filter 198 processed in 2s
# Processing filter 199
# Current loss value: 0.26148143
# Current loss value: 2.0721571
# Current loss value: 7.6689997
# Current loss value: 14.679627
# Current loss value: 23.69741
# Current loss value: 32.45376
# Current loss value: 41.350315
# Current loss value: 53.642315
# Current loss value: 63.504448
# Current loss value: 74.955154
# Current loss value: 90.56197
# Current loss value: 96.72144
# Current loss value: 112.049675
# Current loss value: 121.976494
# Current loss value: 134.79529
# Current loss value: 144.15408
# Current loss value: 159.76613
# Current loss value: 168.94081
# Current loss value: 184.36496
# Current loss value: 193.0163
# Filter 199 processed in 3s

# %%
# we will stich the best 64 filters on a 8 x 8 grid.
n = 8

# %%
# the filters that have the highest loss are assumed to be better-looking.
# we will only keep the top 64 filters.
kept_filters.sort(key=lambda x: x[1], reverse=True)
kept_filters = kept_filters[:n * n]

# %%
# build a black picture with enough space for
# our 8 x 8 filters of size 128 x 128, with a 5px margin in between
margin = 5
width = n * img_width + (n - 1) * margin
height = n * img_height + (n - 1) * margin
stitched_filters = np.zeros((width, height, 3))

# %%
# fill the picture with our saved filters
for i in range(n):
    for j in range(n):
        img, loss = kept_filters[i * n + j]
        stitched_filters[(img_width + margin) * i: (img_width + margin) * i + img_width,
                         (img_height + margin) * j: (img_height + margin) * j + img_height, :] = img

# %%
# save the result to disk
imsave('stitched_filters_%dx%d.png' % (n, n), stitched_filters)

# end keras tutorial
# Out:
# c:\users\garrick\anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
# let's visualize how the model interprets the image data. let's start using a picture that we're familiar with, Pepsi.
# adopted from https://github.com/erikreppel/visualizing_cnns/blob/master/visualize_cnns.ipynb

import cv2

# %%
pepsi = cv2.imread(r'''C:\Users\Garrick\Downloads\pepsi.jpg''')
pepsi = cv2.cvtColor(pepsi, cv2.COLOR_BGR2RGB) #cv2 uses BGR, so reverting back to RGB
plt.imshow(pepsi)

# %%
pepsi.shape
# Out:
# (960, 960, 3)

# %%
pepsi = cv2.resize(pepsi,(224,224))

# %%
pepsi = np.reshape(pepsi,[1,224,224,3])

# %%
pepsi.shape
# Out:
# (1, 224, 224, 3)

# %%
pepsi = np.rollaxis(pepsi, 3, 1)

# %%
pepsi.shape

# image is now in shape appropriate for VGG16BN
# Out:
# (1, 3, 224, 224)

# %%
pepsi_predict_proba = model.predict(pepsi)

# %%
pepsi_predict_class = np.argmax(pepsi_predict_proba)
label_dict[pepsi_predict_class]
# Out:
# 'Airedale'

# %%
# bummer not a good prediction, let's see how confident the model was

pepsi_top_prob = np.max(pepsi_predict_proba)
pepsi_top_prob
# Out:
# 0.36948738

# %%
#let's create a function to apply these same steps over other images

def predict_image(filepath, model=model):
    '''
    Takes a single image and returns class/breed prediction and accuracy
    Dependencies: needs os, cv2 and keras, dependency file or perhaps annex to docker
    Args: filepath of image (no quotes), optional: specify the model, will default to current model in environment
    '''
    img = cv2.imread(filepath)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #cv2 uses BGR, so reverting back to RGB
    print('Uploaded Image...')
    plt.imshow(img)
    
    #resize and reshape for model input
    img = cv2.resize(img,(224,224))
    img = np.reshape(img,[1,224,224,3])
    img = np.rollaxis(img, 3, 1)
    
    #predict
    prediction = model.predict(img)
    
    #print results
    class_predict = np.argmax(prediction)
    breed = label_dict[class_predict]
    print('Woof! The model predicted the breed as...{}!'.format(breed))
    top_prob = np.max(prediction)
    print('...with a confidence of {0:.2f}%.'.format(top_prob*100))

# %%
predict_image('C:\\Users\\Garrick\\Downloads\\IMG_20180221_073001.jpg')
# Out:
# Uploaded Image...
# Woof! The model predicted the breed as...malinois!
# ...with a confidence of 40.51%.

# %%
predict_image('C:\\Users\\Garrick\\Downloads\\pug.jpg')

#yaaaaaaaaas
# this is especially encouraging as pug/bull mastiff was the 2nd most common misclassification
# Out:
# Uploaded Image...
# Woof! The model predicted the breed as...pug!
# ...with a confidence of 48.72%.

# %%
predict_image('C:\\Users\\Garrick\\Downloads\\maggie.jpg')

# trick question, even my parents don't know what kind of dog Maggie is
# Out:
# Uploaded Image...
# Woof! The model predicted the breed as...French_bulldog!
# ...with a confidence of 56.05%.

# %%
predict_image('C:\\Users\\Garrick\\Downloads\\marnie.jpg')
# Out:
# Uploaded Image...
# Woof! The model predicted the breed as...cairn!
# ...with a confidence of 35.88%.

# %%
predict_image('C:\\Users\\Garrick\\Downloads\\barkley.jpg')
# Out:
# Uploaded Image...
# Woof! The model predicted the breed as...French_bulldog!
# ...with a confidence of 97.15%.

# %%
# ok so which breed do I look like?

predict_image('C:\\Users\\Garrick\\Downloads\\1510749_671062136947_5867944268483557830_n.jpg')
# Out:
# Uploaded Image...
# Woof! The model predicted the breed as...vizsla!
# ...with a confidence of 30.78%.
